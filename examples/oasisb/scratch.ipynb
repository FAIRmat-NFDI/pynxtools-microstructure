# %%
import os
from pathlib import Path

prefix = "/home/kaiobach/Research/hu_hu_hu/sprint_fairmat1_final_pm/pynxtools-em/examples/oasisb/openalex"
for entry in Path(prefix).iterdir():
    if entry.is_file():
        file_name = str(entry).rsplit("/", 1)[1]
        if file_name.endswith(".json") and file_name.startswith(("D", "A")):
            os.rename(f"{prefix}/{file_name}", f"{prefix}/{file_name[0:4]}.json")

# %%
# pattern = os.path.join(trg_directory, f"{project_id}.*.mtex.h5")
# for matching_file in glob.glob(pattern):
#     with h5py.File(matching_file, "r") as h5r:
#         if "/entry1/profiling/total_elapsed_time" in h5r:
#             count += 1
# continue
